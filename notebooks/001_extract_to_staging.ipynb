# %% [markdown]
# # Phase 1
#
# ### 1. Identification of the data problem or objective and dataset selection
# All the background information for the project will be in a PDF file in the resources folder.
#
# ### 2. Data extraction or collection

# %% [markdown]
# #### 2.1 Read the data from different sources (CSV files)

# %%
import os
from dotenv import load_dotenv
import psycopg2
from sqlalchemy import create_engine, text
import pandas as pd

# Load environment variables
load_dotenv()

db_staging_user = os.getenv("DB_STAGING_USER")
db_staging_password = os.getenv("DB_STAGING_PASSWORD")
db_staging_host = os.getenv("DB_STAGING_HOST")
db_staging_port = int(os.getenv("DB_STAGING_PORT", 5432))
db_staging_name = os.getenv("DB_STAGING_NAME")

resources_path = os.getenv("RESOURCES_PATH")
mascotas_propietarios_filename = "Mascotas_Propietarios_despensaAnimal_Generated.csv"
propietarios_transacciones_filename = "Propietarios_Transacciones_despensaAnimal_Generated.csv"

if db_staging_user is None:
    raise ValueError("DB_STAGING_USER is not set")
if db_staging_password is None:
    raise ValueError("DB_STAGING_PASSWORD is not set")
if db_staging_host is None:
    raise ValueError("DB_STAGING_HOST is not set")
if db_staging_port is None:
    raise ValueError("DB_STAGING_PORT is not set")
if db_staging_name is None:
    raise ValueError("DB_STAGING_NAME is not set")
if resources_path is None:
    raise ValueError("RESOURCES_PATH is not set")

connStaging = psycopg2.connect(
    dbname=db_staging_name,
    user=db_staging_user,
    password=db_staging_password,
    host=db_staging_host,
    port=db_staging_port
)
connStaging.autocommit = True

# %% [markdown]
# #### 2.2 Create the database engine for the staging data

# %%
db_staging_engine = create_engine(f"postgresql://{db_staging_user}:{db_staging_password}@{db_staging_host}:{db_staging_port}/{db_staging_name}")

# %% [markdown]
# #### 2.3 Read the file "Mascotas_Propietarios_despensaAnimal_Generated.csv" and store it in a database table

# %%
df_mascotas_propietarios = pd.read_csv(f"{resources_path}/{mascotas_propietarios_filename}", delimiter=",", skiprows=1, low_memory=False)

# Rename columns after loading the data
df_mascotas_propietarios.columns = [
    "nombre_mascota",
    "raza",
    "peso",
    "fecha_nacimiento",
    "sexo",
    "temperamento",
    "numero_carnet",
    "estado_reproductivo",
    "numero_partos",
    "color",
    "fecha_fallecimiento",
    "motivo_fallecimiento",
    "comentarios_fallecimiento",
    "nombre_propietario",
    "ciudad",
    "direccion",
    "telefono",
    "whatsapp",
    "email",
    "tipo_documento",
    "numero_documento",
    "profesion",
    "estado",
    "notificaciones_whatsapp"
    ]

# Just print the first 20 rows to test
df_mascotas_propietarios.head(20)

# Store the CSV file into a database 
with db_staging_engine.connect() as conn:
    conn.execute(text("""
        CREATE TABLE IF NOT EXISTS mascotas_propietarios_staging (
            nombre_mascota CHARACTER VARYING,
            raza CHARACTER VARYING,
            peso CHARACTER VARYING,
            fecha_nacimiento DATE,
            sexo CHARACTER VARYING,
            temperamento CHARACTER VARYING,
            numero_carnet CHARACTER VARYING,
            estado_reproductivo CHARACTER VARYING,
            numero_partos CHARACTER VARYING,
            color CHARACTER VARYING,
            fecha_fallecimiento DATE,
            motivo_fallecimiento CHARACTER VARYING,
            comentarios_fallecimiento CHARACTER VARYING,
            nombre_propietario CHARACTER VARYING,
            ciudad CHARACTER VARYING,
            direccion CHARACTER VARYING,
            telefono CHARACTER VARYING,
            whatsapp CHARACTER VARYING,
            email CHARACTER VARYING,
            tipo_documento CHARACTER VARYING,
            numero_documento CHARACTER VARYING,
            profesion CHARACTER VARYING,
            estado CHARACTER VARYING,
            notificaciones_whatsapp CHARACTER VARYING
        );
    """))
    conn.commit()
    print("Table 'mascotas_propietarios_staging' created successfully.")

# Store DataFrame into PostgreSQL table named 'mascotas_propietarios_staging'
df_mascotas_propietarios.to_sql("mascotas_propietarios_staging", db_staging_engine, if_exists="append", index=False)

print("The CSV file data was inserted successfully!")
# Out:
# Table 'mascotas_propietarios_staging' created successfully.
# The CSV file data was inserted successfully!

# %% [markdown]
# #### 2.4 Get data from the "mascotas_propietarios_staging" table to test

# %%
# Just print the first 20 rows to test
df_mascotas_propietarios_verification = pd.read_sql("SELECT * FROM mascotas_propietarios_staging LIMIT 20;", db_staging_engine)
df_mascotas_propietarios_verification
# Out:
#                      nombre_mascota                raza  peso  \
# 0                     THANOS URREGO              Poodle  None
# 1                    TINENK ORDONEZ             Shit-zu  None
# 2                       SIMON VACCA                 PUG  None
# 3                      SUSSY PUERTA  YORK SHIRE TERRIER   3.6
# 4                     EEVEE ANACONA              Poodle  None
# 5                   DULCE RODRIGUEZ            PINSCHER  None
# 6                      EURO LONDOÑO              SPHYNX  None
# 7                     MOLLY GIRALDO             Mestizo  None
# 8             MAXIMILIANO BOHORQUEZ              ANGORA  None
# 9                      LUPE GIRALDO              Poodle  None
# 10                       MAIA LOPEZ             Shit-zu  None
# 11                    CANDY SALAZAR           Pomerania  None
# 12                      LUNA MORENO              BEAGLE  19.4
# 13                       BENJI DIAZ             MESTIZO   2.6
# 14                         BART GIL             Mestizo  None
# 15                    LUNA CASTILLO  YORK SHIRE TERRIER  None
# 16                    COCO PALOMINO              Poodle  None
# 17                     ROCCO GARCIA             PITBULL  None
# 18  VENUS PATRICIA VERGARA MARTINEZ             Mestizo  None
# 19                  PRINCESA LOZANO             Shit-zu  None
#
#    fecha_nacimiento    sexo temperamento numero_carnet estado_reproductivo  \
# 0        2022-09-01   Macho       social          1631              Entero
# 1        2017-02-17  Hembra       social          1650                None
# 2        2021-08-01   Macho       social          1184                None
# 3        2016-10-07  Hembra       social          1359              ENTERA
# 4        2017-09-03  Hembra       social          1632                None
# 5        2020-04-01   Macho       social          1628        Esterilizado
# 6              None   Macho       social          1634                None
# 7        2018-10-15  Hembra       social          1636                None
# 8              None   Macho       social          1657                None
# 9        2018-04-14  Hembra       social          1638                None
# 10       2020-06-30  Hembra       social          1637              Entero
# 11       2018-07-01  Hembra       social            57              ENTERA
# 12       2017-01-27  Hembra       social          1635                None
# 13       2022-10-16   Macho       social          1640                None
# 14       2019-03-16   Macho       social          1658                None
# 15       2021-06-27  Hembra       social          1112                None
# 16       2019-12-15   Macho       social          1668                None
# 17             None   Macho       social          1661                None
# 18       2022-06-19  Hembra       social          1662                None
# 19             None  Hembra       social          1643                None
#
#    numero_partos   color  ...            ciudad  \
# 0           None    None  ...              Cali
# 1           None    None  ...  Santiago de Cali
# 2           None    None  ...              None
# 3        NINGUNO    None  ...              None
# 4           None    None  ...              Cali
# 5           None    None  ...              Cali
# 6           None    None  ...              CALI
# 7           None    None  ...              None
# 8           None    None  ...              None
# 9           None    None  ...              None
# 10          None    None  ...              Cali
# 11          None  DORADO  ...              CALI
# 12          None    None  ...              Cali
# 13          None    None  ...  Santiago de Cali
# 14          None    None  ...  Santiago de Cali
# 15          None    None  ...              CALI
# 16          None    None  ...  Santiago de Cali
# 17          None    None  ...  Santiago de Cali
# 18          None    None  ...  Santiago de Cali
# 19          None    None  ...  Santiago de Cali
#
#                                             direccion    telefono    whatsapp  \
# 0   CRA100 #28-68 VALLE DEL LILI  MADEIRO TORRE 1 ...        None  3207201137
# 1                           cra 85 c # 33- 40 casa 54  3058147632  3157929392
# 2                           Cra98B #45-200 SAN MIGUEL        None  3234191060
# 3                Cra. 98b #34-53 GUADALQUIVIR CASA 64  3134024437  3146096191
# 4                   Calle 45#98B-65 Apto 403, torre 8        None  3216066041
# 5                       CRA98B#48-127  VALLE DEL LILI        None  3175175266
# 6     Calle 13 #98 -10 Multicentro 2 Apto 801 torre 1        None  3225529091
# 7   CLL 28 # 96-186 APTO 301 TORRE D PORTAL DEL LI...        None  3164403237
# 8               Cra 98b # 34-53 Guadalquivir  casa 76        None  3186156608
# 9   CLL 28 # 96-186 APTO 301 TORRE D PORTAL DEL LI...        None  3164403237
# 10  CALLE 55 #99-250 CONDOMINIO REMANSOS DE LILI A...        None  3103663243
# 11                                      CRA 98B#34-53  3046477045  3152002868
# 12                         Carrera 99 #42-80, casa 30        None  3005272579
# 13                                               None        None  3184955551
# 14     cra. 100 28-68 Unidad Madeira apto 103 torre 3        None  3106373464
# 15                                               None  3163432576  3002370514
# 16                                               None        None  3105603885
# 17        CALLE 11A # 116-40 casa 9 ALTOS DE UMBRIA 1        None  3104199219
# 18  calle 54 #98-97 Paseo de la Alameda torre 3 ap...        None  3217684664
# 19           Cra100#28-68 Unidad madeira 1003 torre 3        None  3147696221
#
#                               email tipo_documento numero_documento profesion  \
# 0        lizethurrego1990@gmail.com             CC       1036637677      None
# 1            pa_ordonez@hotmail.com             CC         66987417      None
# 2                              None             CC             None      None
# 3                              None             CC       1006107262      None
# 4              jazmin.dag@gmail.com             CC       1061750508      None
# 5             leidyjoroma@gmail.com             CC          2569816      None
# 6                              None             CC             None      None
# 7                              None             CC       1116275102      None
# 8               Memis0914@gmail.com             CC    1.023.865.148      None
# 9                              None             CC       1116275102      None
# 10         mcamilalopez97@gmail.com             CC       1220469247      None
# 11                             None             CC             None      None
# 12           lasom.osorio@gmail.com             CC         31165306      None
# 13                             None             CC       1006169223      None
# 14              bgilpaulo@gmail.com             CC       3106373464      None
# 15                             None             CC             None      None
# 16                         NO TIENE             CC       1007930087      None
# 17  mariavictoria@compuelite.com.co             CC         29541474      None
# 18     valeriavergara96@hotmail.com             CC       1061788969      None
# 19                             None             CC       1107529343      None
#
#     estado notificaciones_whatsapp
# 0   Activo                  Activo
# 1   Activo                  Activo
# 2   Activo                  Activo
# 3   Activo                  Activo
# 4   Activo                  Activo
# 5   Activo                  Activo
# 6   Activo                  Activo
# 7   Activo                  Activo
# 8   Activo                  Activo
# 9   Activo                  Activo
# 10  Activo                  Activo
# 11  Activo                  Activo
# 12  Activo                  Activo
# 13  Activo                  Activo
# 14  Activo                  Activo
# 15  Activo                  Activo
# 16  Activo                  Activo
# 17  Activo                  Activo
# 18  Activo                  Activo
# 19  Activo                  Activo
#
# [20 rows x 24 columns]

# %% [markdown]
# #### 2.5 Read the file "Propietarios_Transacciones_despensaAnimal_Generated.csv" and store it in a database table

# %%
df_propietarios_transacciones = pd.read_csv(f"{resources_path}/{propietarios_transacciones_filename}", delimiter=",", skiprows=1, dtype={"numero_documento": str}, low_memory=False)

# Rename columns after loading the data
df_propietarios_transacciones.columns = [
    "nombre_propietario",
    "tipo_documento",
    "numero_documento",
    "nombre_mascota",
    "servico_prestado",
    "valor_servicio",
    "fecha_servicio"
    ]

# Just print the first 20 rows to test
df_propietarios_transacciones.head(20)

# Store the CSV file into a database 
with db_staging_engine.connect() as conn:
    conn.execute(text("""
        CREATE TABLE IF NOT EXISTS propietarios_transacciones_staging (
            nombre_propietario CHARACTER VARYING,
            tipo_documento CHARACTER VARYING,
            numero_documento CHARACTER VARYING,
            nombre_mascota CHARACTER VARYING,
            servico_prestado CHARACTER VARYING,
            valor_servicio NUMERIC,
            fecha_servicio DATE            
        );
    """))
    conn.commit()
    print("Table 'propietarios_transacciones_staging' created successfully.")

# Store DataFrame into PostgreSQL table named 'propietarios_transacciones_staging'
df_propietarios_transacciones.to_sql("propietarios_transacciones_staging", db_staging_engine, if_exists="append", index=False)

print("The CSV file data was inserted successfully!")
# Out:
# Table 'propietarios_transacciones_staging' created successfully.
# The CSV file data was inserted successfully!

# %% [markdown]
# #### 2.6 Get data from the "propietarios_transacciones_staging" table to test

# %%
# Just print the first 20 rows to test
df_propietarios_transacciones = pd.read_sql("SELECT * FROM propietarios_transacciones_staging LIMIT 20;", db_staging_engine)
df_propietarios_transacciones
# Out:
#     nombre_propietario tipo_documento numero_documento    nombre_mascota  \
# 0   NICOLAS LOPEZ CANO             CC       1116733904  TOMAS LOPEZ CANO
# 1   NICOLAS LOPEZ CANO             CC       1116733904  TOMAS LOPEZ CANO
# 2   NICOLAS LOPEZ CANO             CC       1116733904  TOMAS LOPEZ CANO
# 3   NICOLAS LOPEZ CANO             CC       1116733904  TOMAS LOPEZ CANO
# 4   NICOLAS LOPEZ CANO             CC       1116733904  TOMAS LOPEZ CANO
# 5   NICOLAS LOPEZ CANO             CC       1116733904  TOMAS LOPEZ CANO
# 6        LIZETH URREGO             CC       1036637677     THANOS URREGO
# 7        PAOLA ORDONEZ             CC         66987417    TINENK ORDONEZ
# 8        PAOLA ORDONEZ             CC         66987417    TINENK ORDONEZ
# 9        PAOLA ORDONEZ             CC         66987417    TINENK ORDONEZ
# 10       PAOLA ORDONEZ             CC         66987417    TINENK ORDONEZ
# 11       PAOLA ORDONEZ             CC         66987417    TINENK ORDONEZ
# 12       PAOLA ORDONEZ             CC         66987417    TINENK ORDONEZ
# 13       PAOLA ORDONEZ             CC         66987417    TINENK ORDONEZ
# 14       PAOLA ORDONEZ             CC         66987417    TINENK ORDONEZ
# 15       PAOLA ORDONEZ             CC         66987417    TINENK ORDONEZ
# 16       PAOLA ORDONEZ             CC         66987417    TINENK ORDONEZ
# 17       PAOLA ORDONEZ             CC         66987417    TINENK ORDONEZ
# 18       PAOLA ORDONEZ             CC         66987417    TINENK ORDONEZ
# 19       PAOLA ORDONEZ             CC         66987417    TINENK ORDONEZ
#
#    servico_prestado  valor_servicio fecha_servicio
# 0        Vacunación       1406023.0     2017-11-22
# 1             Otros        125698.0     2019-10-06
# 2        Peluquería       1815514.0     2019-05-18
# 3             Otros       1592900.0     2023-03-20
# 4        Vacunación        147163.0     2022-10-08
# 5        Peluquería       1230361.0     2024-05-19
# 6         Eutanasia        105455.0     2025-03-10
# 7     Desparacitada        911422.0     2017-10-30
# 8     Desparacitada       1061883.0     2020-07-12
# 9   Venta Alimentos       1019826.0     2017-05-15
# 10       Vacunación       1824815.0     2018-11-22
# 11             Baño       1040718.0     2021-03-15
# 12  Venta Alimentos        449933.0     2017-05-06
# 13  Venta Alimentos       1438942.0     2018-09-25
# 14       Vacunación       1077173.0     2022-05-14
# 15  Venta Alimentos       1891186.0     2021-07-09
# 16       Peluquería        482092.0     2018-11-27
# 17             Baño        313887.0     2021-11-17
# 18            Otros        538196.0     2023-08-27
# 19       Vacunación        992109.0     2017-03-08
